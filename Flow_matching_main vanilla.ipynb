# %%
import time
import torch

from torch import nn, Tensor
from torch.utils.data import DataLoader, TensorDataset

import flow_matching
from flow_matching.path.scheduler import CondOTScheduler
from flow_matching.path import AffineProbPath
from flow_matching.solver import Solver, ODESolver
from flow_matching.utils import ModelWrapper
from Distributions2 import *
# visualization
import matplotlib.pyplot as plt

from matplotlib import cm
from flow import build_ttf_m
from network import MLP

# To avoide meshgrid warning
import warnings

warnings.filterwarnings("ignore", category=UserWarning, module='torch')

# %%
if torch.cuda.is_available():
    device = 'cuda:0'
    print('Using gpu')
else:
    device = 'cpu'
    print('Using cpu.')
torch.manual_seed(42)
seed=42
# Out:
# Using gpu

# %% [markdown]
# ## Sampling data

# %%
#PRINT MIX OF STUDENT-T
dof_og=1
ST_DATA,objectz=samplestudentT_4(50,dof_og,40000)
# plt.scatter(ST_DATA[:,0],ST_DATA[:,1],c="blue")

# %%
#GETTING THE Data split and TAIL INDEX ESTIMATES
from generate_splits import generate_data_split

# %%
Data_Splt=generate_data_split('gppg', seed, 'dummy',ST_DATA)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [01:03<00:00, 31.64s/it]

# %%
Data_Splt['metadata']
# Out:
# {'dfs': [1.1737037772202683, 0.9461591723366531],
#  'pos_dfs': [0.0, 1.0584125863547804],
#  'neg_dfs': [0.5584578360608328, 0.870418293978243],
#  'mean': [-2.426814, -0.6382829],
#  'std': [350.42422, 127.15294],
#  'seed': 42}

# %% [markdown]
# ## Building the Tail Model

# %%
# def ttf_rqs(dim, dfs):
#     return flows.build_ttf_m(
#         dim,
#         model_kwargs=dict(
#             fix_tails=False,
#             pos_tail_init=[
#                 float(t.cpu()) for t in torch.distributions.Uniform(low=0.05, high=1.0).sample([dim])
#             ],
#             neg_tail_init=[
#                 float(t.cpu()) for t in torch.distributions.Uniform(low=0.05, high=1.0).sample([dim])
#             ]
#         )
#     )


# def ttf_rqs_fix(dim, dfs):
#     return build_ttf_m(
#         dim,
#         model_kwargs=dict(
#             fix_tails=False,#ADITYA CHANGED THIS
#             pos_tail_init=[1 / df if df != 0.0 else 1e-4 for df in dfs['metadata']['pos_dfs']],  #DIFFFERENT FROM MAIN CODE
#             neg_tail_init=[1 / df if df != 0.0 else 1e-4 for df in dfs['metadata']['neg_dfs']],  #DIFFFERENT FROM MAIN CODE
#         )
#     )

# %%
# list(ttf_rqs_fix(2,Data_Splt).parameters())

# %%
# training arguments
lr = 0.001
batch_size = 4096
iterations = 800
print_every = 1
hidden_dim = 512
dimension=2
device
# velocity field model init
vf = MLP(input_dim=2, time_dim=1, hidden_dim=hidden_dim).to(device)
# data2noiseTransform=ttf_rqs_fix(dimension,Data_Splt).to(device)

# %%
# list(data2noiseTransform.parameters())
# data2noiseTransform(torch.randn(22,2).to(device))[0].shape

# %%
trn_ix = Data_Splt["split"]["trn"]
val_ix = Data_Splt["split"]["val"]
tst_ix = Data_Splt["split"]["tst"]

mean = torch.tensor(Data_Splt['metadata']["mean"])
scale = torch.tensor(Data_Splt['metadata']["std"])

x_trn =ST_DATA[trn_ix] #(ST_DATA[trn_ix] - mean) / scale
x_val =ST_DATA[val_ix] #(ST_DATA[val_ix] - mean) / scale
x_tst =ST_DATA[tst_ix] #(ST_DATA[tst_ix] - mean) / scale

# %%
# def reverse_normalization(x):
#     y=(x*scale)+mean
#     return(y)

# %%
train_dataset = TensorDataset(x_trn)


# Create DataLoader
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
jo=0 #counter
# instantiate an affine path object
path = AffineProbPath(scheduler=CondOTScheduler())

# init optimizer
optim = torch.optim.Adam(vf.parameters(), lr=lr/10)
# optim2=torch.optim.Adam(data2noiseTransform.parameters(), lr=lr)
# train
start_time = time.time()
for i in range(iterations):
    for data in train_loader:
        optim.zero_grad()
        # optim2.zero_grad()
        # sample data : in this case, (X_0,X_1) ~ pi(X_0,X_1) = N(X_0|0,I)q(X_1)
        # print(data[0].shape)
        x_1_H=data[0].float().to(device)
        x_0 = torch.randn_like(x_1_H).float().to(device)

        x_1=x_1_H#data2noiseTransform(x_1_H)[0] #Heavy tail to light tail
       


        # sample time 
        t = torch.rand(x_1.shape[0]).to(device)

        # sample probability path
        path_sample = path.sample(t=t, x_0=x_0, x_1=x_1)
        # print(vf(path_sample.x_t,path_sample.t))

        # flow matching l2 loss
        
        loss = torch.pow( vf(path_sample.x_t,path_sample.t) - path_sample.dx_t, 2).mean()

        # optimizer step
        loss.backward() # backward
        optim.step() # update
        # optim2.step()

    # log loss
        jo=jo+1
        if (jo+1) % print_every == 0:
            elapsed = time.time() - start_time
            print('| iter {:6d} | {:5.2f} ms/step | loss {:8.3f} '
                .format(jo+1, elapsed*1000/print_every, loss.item()))
            start_time = time.time()
# Out:
# | iter      2 | 5258.07 ms/step | loss 25697.670
# | iter      3 | 64.08 ms/step | loss 1586.904
# | iter      4 | 33.57 ms/step | loss 358933.375
# | iter      5 | 22.66 ms/step | loss 3009.858
# | iter      6 | 28.46 ms/step | loss 4288.414
# | iter      7 | 337.07 ms/step | loss 332097.031
# | iter      8 | 23.53 ms/step | loss 25267.373
# | iter      9 | 21.35 ms/step | loss 4910.379
# | iter     10 | 21.60 ms/step | loss 4964.810
# | iter     11 | 22.98 ms/step | loss 22530.203
# | iter     12 | 25.34 ms/step | loss 2829.117
# | iter     13 | 23.00 ms/step | loss 373853.000
# | iter     14 | 23.02 ms/step | loss 4081.373
# | iter     15 | 22.41 ms/step | loss 284280.812
# | iter     16 | 23.60 ms/step | loss 2556.458
# | iter     17 | 196.47 ms/step | loss 23543.998
# | iter     18 | 33.56 ms/step | loss 279776.469
# | iter     19 | 22.91 ms/step | loss 5687.796
# | iter     20 | 15.63 ms/step | loss 21633.053
# | iter     21 | 34.39 ms/step | loss 2122.997
# | iter     22 | 28.64 ms/step | loss 2979.051
# | iter     23 | 31.25 ms/step | loss 26565.350
# | iter     24 | 25.84 ms/step | loss 3154.459
# | iter     25 | 15.63 ms/step | loss 336125.438
# | iter     26 | 173.93 ms/step | loss 3503.765
# | iter     27 | 36.20 ms/step | loss 281422.656
# | iter     28 | 21.64 ms/step | loss 17131.402
# | iter     29 | 11.33 ms/step | loss 2510.549
# | iter     30 | 31.26 ms/step | loss 339276.781
# | iter     31 | 42.51 ms/step | loss 4692.873
# | iter     32 | 15.63 ms/step | loss 2307.245
# | iter     33 | 41.13 ms/step | loss 18193.770
# | iter     34 | 26.17 ms/step | loss 5216.675
# | iter     35 | 36.77 ms/step | loss 2565.945
# | iter     36 | 158.02 ms/step | loss 1510.749
# | iter     37 | 27.52 ms/step | loss 292679.156
# | iter     38 | 29.90 ms/step | loss 2033.634
# | iter     39 | 41.34 ms/step | loss 2341.662
# | iter     40 | 30.82 ms/step | loss 118251.547
# | iter     41 | 22.94 ms/step | loss 9610.718
# | iter     42 | 24.78 ms/step | loss 1888.718
# | iter     43 | 34.19 ms/step | loss 1935.986
# | iter     44 | 107.59 ms/step | loss 89275.078
# | iter     45 | 15.22 ms/step | loss 3623.108
# | iter     46 | 25.52 ms/step | loss 2653.382
# | iter     47 | 17.08 ms/step | loss 8788.423
# | iter     48 | 22.38 ms/step | loss 100263.391
# | iter     49 | 17.48 ms/step | loss 2115.954
# | iter     50 | 32.96 ms/step | loss 7228.190
# | iter     51 | 21.54 ms/step | loss 3329.158
# | iter     52 | 15.63 ms/step | loss 2495.962
# | iter     53 | 20.31 ms/step | loss  726.801
# | iter     54 | 88.97 ms/step | loss 21281.549
# | iter     55 | 18.06 ms/step | loss  794.712
# | iter     56 | 15.63 ms/step | loss 2147.668
# | iter     57 | 15.62 ms/step | loss 16106.292
# | iter     58 | 36.31 ms/step | loss 1026.285
# | iter     59 | 26.20 ms/step | loss 1670.334
# | iter     60 | 31.67 ms/step | loss 5204.266
# | iter     61 | 23.88 ms/step | loss 2501.899
# | iter     62 | 24.95 ms/step | loss  572.221
# | iter     63 | 30.83 ms/step | loss  744.846
# | iter     64 | 95.69 ms/step | loss 165755.328
# | iter     65 | 37.05 ms/step | loss 1340.832
# | iter     66 | 31.25 ms/step | loss 3657.051
# | iter     67 | 21.67 ms/step | loss 44256.668
# | iter     68 | 15.63 ms/step | loss  895.422
# | iter     69 | 31.26 ms/step | loss 2377.272
# | iter     70 | 22.97 ms/step | loss 2602.125
# | iter     71 | 31.25 ms/step | loss 349728.344
# | iter     72 | 32.07 ms/step | loss  905.440
# | iter     73 | 33.81 ms/step | loss 1421.303
# | iter     74 | 99.34 ms/step | loss 2698.550
# | iter     75 | 15.65 ms/step | loss  632.416
# | iter     76 | 26.94 ms/step | loss 1013.109
# | iter     77 | 16.33 ms/step | loss 12028.380
# | iter     78 | 15.63 ms/step | loss  647.777
# | iter     79 | 21.75 ms/step | loss 175623.984
# | iter     80 | 24.01 ms/step | loss 1213.490
# | iter     81 | 15.62 ms/step | loss  979.696
# | iter     82 | 28.97 ms/step | loss 14923.666
# | iter     83 | 96.06 ms/step | loss  840.286
# | iter     84 | 15.62 ms/step | loss 8698.735
# | iter     85 | 16.00 ms/step | loss  680.199
# | iter     86 | 22.30 ms/step | loss  770.291
# | iter     87 | 17.79 ms/step | loss 1276.472
# | iter     88 | 17.26 ms/step | loss 2346.968
# | iter     89 | 27.82 ms/step | loss 294440.031
# | iter     90 | 15.63 ms/step | loss 170906.688
# | iter     91 | 15.62 ms/step | loss  715.572
# | iter     92 | 29.33 ms/step | loss 4509.513
# | iter     93 | 95.77 ms/step | loss  686.591
# | iter     94 | 31.16 ms/step | loss 20946.221
# | iter     95 | 16.58 ms/step | loss  499.746
# | iter     96 | 22.78 ms/step | loss 126879.438
# | iter     97 | 31.25 ms/step | loss 1093.487
# | iter     98 | 30.32 ms/step | loss  950.709
# | iter     99 | 22.45 ms/step | loss  460.412
# | iter    100 | 13.51 ms/step | loss 1180.710
# | iter    101 | 117.93 ms/step | loss 127988.367
# | iter    102 | 21.98 ms/step | loss 1203.415
# | iter    103 | 31.26 ms/step | loss 19869.287
# | iter    104 | 31.20 ms/step | loss 32411.092
# | iter    105 | 15.65 ms/step | loss 1052.821
# | iter    106 | 15.64 ms/step | loss  614.078
# | iter    107 | 31.27 ms/step | loss  817.281
# | iter    108 | 16.72 ms/step | loss 10425.573
# | iter    109 | 15.64 ms/step | loss 12668.634
# | iter    110 | 32.83 ms/step | loss 1366.394
# | iter    111 | 137.62 ms/step | loss 1672.152
# | iter    112 | 15.63 ms/step | loss 131401.938
# | iter    113 | 15.63 ms/step | loss 5092.057
# | iter    114 | 16.39 ms/step | loss 2300.071
# | iter    115 | 34.02 ms/step | loss 63753.012
# | iter    116 | 34.20 ms/step | loss 1109.899
# | iter    117 | 31.25 ms/step | loss  514.620
# | iter    118 | 31.25 ms/step | loss  783.163
# | iter    119 | 31.25 ms/step | loss 5506.528
# | iter    120 | 31.25 ms/step | loss  930.300
# | iter    121 | 123.86 ms/step | loss  631.913
# | iter    122 | 35.58 ms/step | loss  508.608
# | iter    123 |  9.57 ms/step | loss 356559.312
# | iter    124 | 28.57 ms/step | loss  723.938
# | iter    125 | 14.70 ms/step | loss 1412.104
# | iter    126 | 20.80 ms/step | loss  868.906
# | iter    127 | 15.64 ms/step | loss 2657.317
# | iter    128 | 31.24 ms/step | loss 1845.011
# | iter    129 | 21.30 ms/step | loss  796.432
# | iter    130 | 31.24 ms/step | loss  670.550
# | iter    131 | 114.17 ms/step | loss 1119.162
# | iter    132 | 17.82 ms/step | loss 10337.861
# | iter    133 | 15.64 ms/step | loss  882.292
# | iter    134 | 31.24 ms/step | loss  985.556
# | iter    135 | 26.46 ms/step | loss 3554.848
# | iter    136 | 15.64 ms/step | loss  627.325
# | iter    137 | 15.63 ms/step | loss 1276.803
# | iter    138 | 15.72 ms/step | loss 3293.605
# | iter    139 | 95.68 ms/step | loss 29330.793
# | iter    140 | 15.64 ms/step | loss 1797.282
# | iter    141 | 31.25 ms/step | loss  956.582
# | iter    142 | 32.93 ms/step | loss  749.544
# | iter    143 | 15.64 ms/step | loss 2772.174
# | iter    144 | 22.84 ms/step | loss 86428.016
# | iter    145 | 20.73 ms/step | loss 1089.560
# | iter    146 | 31.26 ms/step | loss 16828.006
# | iter    147 | 31.27 ms/step | loss  577.052
# | iter    148 | 92.77 ms/step | loss 2074.625
# | iter    149 | 13.36 ms/step | loss 1134.537
# | iter    150 | 15.63 ms/step | loss 2325.763
# | iter    151 | 15.64 ms/step | loss  914.896
# | iter    152 | 23.41 ms/step | loss 21540.201
# | iter    153 | 15.62 ms/step | loss  799.679
# | iter    154 | 15.63 ms/step | loss  823.370
# | iter    155 | 20.96 ms/step | loss 41158.434
# | iter    156 | 12.28 ms/step | loss 9249.425
# | iter    157 | 15.63 ms/step | loss  550.104
# | iter    158 | 102.60 ms/step | loss 1222.992
# | iter    159 | 21.98 ms/step | loss 1630.470
# | iter    160 | 20.42 ms/step | loss 4102.231
# | iter    161 | 19.69 ms/step | loss 1148.847
# | iter    162 | 20.70 ms/step | loss 1197.923
# | iter    163 | 15.64 ms/step | loss 1525.667
# | iter    164 | 17.02 ms/step | loss 13204.940
# | iter    165 | 17.12 ms/step | loss 4098.355
# | iter    166 | 24.32 ms/step | loss 4593.652
# | iter    167 | 92.67 ms/step | loss 52426.723
# | iter    168 | 21.64 ms/step | loss  586.474
# | iter    169 | 15.63 ms/step | loss 1019.464
# | iter    170 | 23.51 ms/step | loss 1421.952
# | iter    171 | 29.27 ms/step | loss  514.395
# | iter    172 | 15.63 ms/step | loss 1100.325
# | iter    173 | 15.63 ms/step | loss 135067.734
# | iter    174 | 31.27 ms/step | loss 19219.078
# | iter    175 | 25.36 ms/step | loss 1523.464
# | iter    176 | 25.54 ms/step | loss 1307.758
# | iter    177 | 27.01 ms/step | loss  624.329
# | iter    178 | 113.37 ms/step | loss 178220.094
# | iter    179 | 25.09 ms/step | loss 2035.859
# | iter    180 | 17.60 ms/step | loss  595.787
# | iter    181 |  6.19 ms/step | loss 9061.314
# | iter    182 | 15.63 ms/step | loss 1156.286
# | iter    183 | 16.55 ms/step | loss 227171.016
# | iter    184 | 22.68 ms/step | loss  540.873
# | iter    185 | 31.78 ms/step | loss  513.272
# | iter    186 | 13.10 ms/step | loss 39580.176
# | iter    187 | 15.64 ms/step | loss  565.276
# | iter    188 | 92.70 ms/step | loss 20609.172
# | iter    189 | 15.61 ms/step | loss 1591.477
# | iter    190 | 15.63 ms/step | loss 15667.003
# | iter    191 | 12.80 ms/step | loss  859.010
# | iter    192 | 33.44 ms/step | loss 25349.527
# | iter    193 | 15.63 ms/step | loss  591.559
# | iter    194 | 11.11 ms/step | loss 1963.122
# | iter    195 | 31.25 ms/step | loss 352688.938
# | iter    196 | 25.85 ms/step | loss  856.639
# | iter    197 | 101.02 ms/step | loss  535.408
# | iter    198 | 21.54 ms/step | loss  851.712
# | iter    199 | 17.05 ms/step | loss  575.745
# | iter    200 | 24.96 ms/step | loss 25066.242
# | iter    201 | 17.65 ms/step | loss 19135.410
# | iter    202 | 25.51 ms/step | loss  473.233
# | iter    203 | 25.65 ms/step | loss 22337.359
# | iter    204 | 24.83 ms/step | loss  433.479
# | iter    205 | 99.49 ms/step | loss 6746.978
# | iter    206 | 18.37 ms/step | loss  488.458
# | iter    207 | 24.96 ms/step | loss 1388.270
# | iter    208 | 25.14 ms/step | loss 1633.081
# | iter    209 | 27.22 ms/step | loss 7258.664
# | iter    210 | 26.12 ms/step | loss 2766.881
# | iter    211 | 17.29 ms/step | loss  928.007
# | iter    212 | 16.52 ms/step | loss 130991.922
# | iter    213 | 16.20 ms/step | loss  827.311
# | iter    214 | 106.21 ms/step | loss 136224.766
# | iter    215 | 15.63 ms/step | loss 2496.630
# | iter    216 | 29.83 ms/step | loss  641.736
# | iter    217 | 24.63 ms/step | loss 1397.025
# | iter    218 | 25.00 ms/step | loss 144877.375
# | iter    219 | 24.94 ms/step | loss  708.719
# | iter    220 | 23.45 ms/step | loss 1718.592
# | iter    221 | 31.25 ms/step | loss 2107.448
# | iter    222 | 28.35 ms/step | loss 1457.944
# | iter    223 | 25.58 ms/step | loss  777.344
# | iter    224 | 102.86 ms/step | loss 2400.180
# | iter    225 | 24.39 ms/step | loss 2514.440
# | iter    226 | 25.30 ms/step | loss 276499.406
# | iter    227 | 16.27 ms/step | loss  660.198
# | iter    228 | 25.54 ms/step | loss 1124.102
# | iter    229 | 26.04 ms/step | loss  775.187
# | iter    230 | 23.88 ms/step | loss  612.851
# | iter    231 | 23.77 ms/step | loss 17989.500
# | iter    232 | 16.00 ms/step | loss 164897.031
# | iter    233 | 17.32 ms/step | loss  593.874
# | iter    234 | 17.13 ms/step | loss 2064.407
# | iter    235 | 99.13 ms/step | loss 175289.188
# | iter    236 | 13.21 ms/step | loss 1110.202
# | iter    237 | 20.73 ms/step | loss 1228.358
# | iter    238 | 15.75 ms/step | loss 1502.245
# | iter    239 | 24.99 ms/step | loss 1171.635
# | iter    240 | 21.94 ms/step | loss 22745.072
# | iter    241 | 21.91 ms/step | loss 1274.186
# | iter    242 | 21.71 ms/step | loss  597.115
# | iter    243 | 16.74 ms/step | loss 20195.678
# | iter    244 | 20.51 ms/step | loss 1455.781
# | iter    245 | 87.81 ms/step | loss 13993.893
# | iter    246 | 19.53 ms/step | loss 199917.188
# | iter    247 | 20.74 ms/step | loss 1309.176
# | iter    248 | 15.28 ms/step | loss  910.936
# | iter    249 | 16.86 ms/step | loss  622.744
# | iter    250 | 17.24 ms/step | loss 238782.609
# | iter    251 | 16.67 ms/step | loss 8966.031
# | iter    252 | 25.19 ms/step | loss  985.398
# | iter    253 | 21.97 ms/step | loss 2522.195
# | iter    254 | 98.17 ms/step | loss 1580.608
# | iter    255 | 18.03 ms/step | loss 13201.716
# | iter    256 | 23.69 ms/step | loss  963.886
# | iter    257 | 25.27 ms/step | loss 73983.508
# | iter    258 | 16.76 ms/step | loss  476.634
# | iter    259 | 24.72 ms/step | loss  599.950
# | iter    260 | 27.61 ms/step | loss 7718.632
# | iter    261 | 22.11 ms/step | loss 2996.781
# | iter    262 | 99.95 ms/step | loss 44045.355
# | iter    263 | 22.57 ms/step | loss 1550.150
# | iter    264 | 26.04 ms/step | loss  772.874
# | iter    265 | 21.44 ms/step | loss 3101.247
# | iter    266 | 24.23 ms/step | loss 17187.033
# | iter    267 | 29.85 ms/step | loss 1201.460
# | iter    268 | 16.82 ms/step | loss 1107.466
# | iter    269 | 20.80 ms/step | loss 6585.791
# | iter    270 | 29.72 ms/step | loss 2622.481
# | iter    271 | 91.21 ms/step | loss 174747.234
# | iter    272 | 22.74 ms/step | loss  592.465
# | iter    273 | 25.49 ms/step | loss  918.387
# | iter    274 | 16.67 ms/step | loss 348481.438
# | iter    275 | 21.86 ms/step | loss  705.726
# | iter    276 | 25.64 ms/step | loss 15337.878
# | iter    277 | 24.48 ms/step | loss 1584.645
# | iter    278 | 23.81 ms/step | loss 1077.785
# | iter    279 | 25.87 ms/step | loss 22896.711
# | iter    280 | 17.34 ms/step | loss 58871.246
# | iter    281 | 21.41 ms/step | loss  900.174
# | iter    282 | 94.43 ms/step | loss  833.185
# | iter    283 | 21.20 ms/step | loss 10610.490
# | iter    284 | 23.16 ms/step | loss 2110.304
# | iter    285 | 20.41 ms/step | loss 1412.157
# | iter    286 | 20.34 ms/step | loss  493.529
# | iter    287 | 21.55 ms/step | loss 1074.637
# | iter    288 | 24.53 ms/step | loss 1352.941
# | iter    289 | 28.28 ms/step | loss 33260.512
# | iter    290 | 13.97 ms/step | loss 200050.828
# | iter    291 | 93.54 ms/step | loss 1457.643
# | iter    292 | 24.84 ms/step | loss  703.110
# | iter    293 | 20.70 ms/step | loss 22705.434
# | iter    294 | 23.92 ms/step | loss 13714.141
# | iter    295 | 24.52 ms/step | loss  594.777
# | iter    296 | 21.93 ms/step | loss 2550.444
# | iter    297 | 25.04 ms/step | loss  869.294
# | iter    298 | 24.64 ms/step | loss 236187.797
# | iter    299 | 20.84 ms/step | loss 7732.928
# | iter    300 | 97.50 ms/step | loss  588.595
# | iter    301 | 17.50 ms/step | loss  618.682
# | iter    302 | 29.55 ms/step | loss  452.155
# | iter    303 | 17.81 ms/step | loss 13604.979
# | iter    304 | 22.63 ms/step | loss 17737.412
# | iter    305 | 19.91 ms/step | loss 2664.926
# | iter    306 | 20.55 ms/step | loss 55761.219
# | iter    307 | 21.71 ms/step | loss  420.395
# | iter    308 | 23.78 ms/step | loss 2441.585
# | iter    309 | 89.34 ms/step | loss 1806.832
# | iter    310 | 22.35 ms/step | loss 43813.965
# | iter    311 | 24.69 ms/step | loss  623.714
# | iter    312 | 27.72 ms/step | loss 2067.292
# | iter    313 | 25.28 ms/step | loss  804.865
# | iter    314 | 25.14 ms/step | loss 1574.329
# | iter    315 | 26.74 ms/step | loss 8772.132
# | iter    316 | 25.36 ms/step | loss 141492.797
# | iter    317 | 21.49 ms/step | loss 1817.908
# | iter    318 | 104.51 ms/step | loss 1532.042
# | iter    319 | 22.54 ms/step | loss 1161.806
# | iter    320 | 21.17 ms/step | loss  555.263
# | iter    321 | 20.58 ms/step | loss 31610.578
# | iter    322 | 24.87 ms/step | loss 193505.219
# | iter    323 | 20.79 ms/step | loss  785.870
# | iter    324 | 21.17 ms/step | loss 1091.572
# | iter    325 | 17.35 ms/step | loss  819.685
# | iter    326 | 25.03 ms/step | loss 3940.881
# | iter    327 | 24.04 ms/step | loss 189947.844
# | iter    328 | 104.75 ms/step | loss 1158.112
# | iter    329 | 24.52 ms/step | loss 3210.218
# | iter    330 | 22.57 ms/step | loss 1378.172
# | iter    331 | 21.67 ms/step | loss  504.351
# | iter    332 | 16.84 ms/step | loss 19988.889
# | iter    333 | 23.34 ms/step | loss 2677.851
# | iter    334 | 34.51 ms/step | loss 218885.484
# | iter    335 | 24.31 ms/step | loss 7759.298
# | iter    336 | 22.22 ms/step | loss 1154.816
# | iter    337 | 17.33 ms/step | loss 1212.646
# | iter    338 | 109.17 ms/step | loss  637.628
# | iter    339 | 26.57 ms/step | loss 3048.758
# | iter    340 | 23.37 ms/step | loss 3444.414
# | iter    341 | 24.10 ms/step | loss 86941.664
# | iter    342 | 15.35 ms/step | loss  793.791
# | iter    343 | 16.49 ms/step | loss  565.681
# | iter    344 | 24.23 ms/step | loss 27956.781
# | iter    345 | 21.38 ms/step | loss  475.363
# | iter    346 | 16.75 ms/step | loss 110675.336
# | iter    347 | 24.30 ms/step | loss 1659.341
# | iter    348 | 95.96 ms/step | loss  708.990
# | iter    349 | 25.34 ms/step | loss  411.264
# | iter    350 | 21.19 ms/step | loss 5393.251
# | iter    351 | 20.69 ms/step | loss 21483.982
# | iter    352 | 25.05 ms/step | loss  432.496
# | iter    353 | 16.54 ms/step | loss 1534.223
# | iter    354 | 22.39 ms/step | loss  575.093
# | iter    355 | 25.46 ms/step | loss 2243.524
# | iter    356 | 20.82 ms/step | loss 2669.014
# | iter    357 | 19.25 ms/step | loss 381169.344
# | iter    358 | 97.74 ms/step | loss  888.343
# | iter    359 | 22.52 ms/step | loss 14550.896
# | iter    360 | 27.69 ms/step | loss 4714.574
# | iter    361 | 19.76 ms/step | loss  808.401
# | iter    362 | 20.59 ms/step | loss 169091.750
# | iter    363 | 27.65 ms/step | loss  830.146
# | iter    364 | 25.34 ms/step | loss 1097.081
# | iter    365 | 25.38 ms/step | loss  729.118
# | iter    366 | 23.12 ms/step | loss 6106.285
# | iter    367 | 91.28 ms/step | loss  927.412
# | iter    368 | 21.46 ms/step | loss  626.881
# | iter    369 | 25.76 ms/step | loss 30387.439
# | iter    370 | 25.53 ms/step | loss  489.829
# | iter    371 | 20.37 ms/step | loss 9854.092
# | iter    372 | 23.18 ms/step | loss 97860.203
# | iter    373 | 24.75 ms/step | loss  964.218
# | iter    374 | 22.41 ms/step | loss  324.867
# | iter    375 | 29.05 ms/step | loss 40787.234
# | iter    376 | 17.22 ms/step | loss 22472.648
# | iter    377 | 97.36 ms/step | loss  671.387
# | iter    378 | 25.26 ms/step | loss 4857.466
# | iter    379 | 14.99 ms/step | loss 1919.859
# | iter    380 | 24.34 ms/step | loss 1030.584
# | iter    381 | 21.82 ms/step | loss 1494.537
# | iter    382 | 24.16 ms/step | loss 2325.189
# | iter    383 | 25.13 ms/step | loss  442.238
# | iter    384 | 17.79 ms/step | loss 5653.088
# | iter    385 | 88.36 ms/step | loss 24345.465
# | iter    386 | 17.26 ms/step | loss  867.175
# | iter    387 | 22.45 ms/step | loss 6992.704
# | iter    388 | 25.87 ms/step | loss 212266.281
# | iter    389 | 24.05 ms/step | loss  835.269
# | iter    390 | 20.38 ms/step | loss  943.448
# | iter    391 | 27.52 ms/step | loss  569.297
# | iter    392 | 17.67 ms/step | loss 10566.748
# | iter    393 | 17.21 ms/step | loss 56463.367
# | iter    394 | 25.30 ms/step | loss 1373.343
# | iter    395 | 99.58 ms/step | loss  957.594
# | iter    396 | 23.39 ms/step | loss 182417.969
# | iter    397 | 16.16 ms/step | loss 3244.303
# | iter    398 | 25.28 ms/step | loss 16572.432
# | iter    399 | 24.44 ms/step | loss 1779.862
# | iter    400 | 21.52 ms/step | loss  520.620
# | iter    401 | 26.80 ms/step | loss  401.219
# | iter    402 | 26.26 ms/step | loss 1075.309
# | iter    403 | 19.22 ms/step | loss 141832.672
# | iter    404 | 21.76 ms/step | loss 5287.861
# | iter    405 | 99.80 ms/step | loss  723.277
# | iter    406 | 22.85 ms/step | loss 1010.422
# | iter    407 | 25.31 ms/step | loss 6514.334
# | iter    408 | 21.83 ms/step | loss 1031.284
# | iter    409 | 19.50 ms/step | loss 1656.531
# | iter    410 | 17.81 ms/step | loss 138516.859
# | iter    411 | 16.97 ms/step | loss 2795.971
# | iter    412 | 21.74 ms/step | loss 1077.384
# | iter    413 | 21.44 ms/step | loss  898.448
# | iter    414 | 24.22 ms/step | loss 80124.453
# | iter    415 | 95.88 ms/step | loss 1260.299
# | iter    416 | 24.14 ms/step | loss 11068.630
# | iter    417 | 24.95 ms/step | loss  778.075
# | iter    418 | 17.03 ms/step | loss  535.813
# | iter    419 | 24.06 ms/step | loss 1711.511
# | iter    420 | 26.41 ms/step | loss 252973.266
# | iter    421 | 21.28 ms/step | loss  775.751
# | iter    422 | 12.30 ms/step | loss  776.307
# | iter    423 | 100.11 ms/step | loss  936.387
# | iter    424 | 15.27 ms/step | loss  556.452
# | iter    425 | 16.85 ms/step | loss 12032.469
# | iter    426 | 18.75 ms/step | loss 6284.685
# | iter    427 | 21.73 ms/step | loss 1341.708
# | iter    428 | 22.32 ms/step | loss  512.235
# | iter    429 | 19.95 ms/step | loss  644.566
# | iter    430 | 15.42 ms/step | loss 1163.991
# | iter    431 | 25.23 ms/step | loss 49804.043
# | iter    432 | 96.65 ms/step | loss 1795.632
# | iter    433 | 26.05 ms/step | loss  670.510
# | iter    434 | 14.97 ms/step | loss 3208.619
# | iter    435 | 20.05 ms/step | loss 198773.969
# | iter    436 | 17.50 ms/step | loss 1104.953
# | iter    437 | 16.09 ms/step | loss  595.811
# | iter    438 | 26.48 ms/step | loss  878.621
# | iter    439 | 23.41 ms/step | loss 21240.859
# | iter    440 | 17.30 ms/step | loss 25062.994
# | iter    441 | 18.72 ms/step | loss 1135.743
# | iter    442 | 93.57 ms/step | loss  684.352
# | iter    443 | 21.75 ms/step | loss  830.388
# | iter    444 | 20.97 ms/step | loss 176757.234
# | iter    445 | 21.85 ms/step | loss 5672.754
# | iter    446 | 25.40 ms/step | loss  553.217
# | iter    447 | 19.32 ms/step | loss 1342.315
# | iter    448 | 26.50 ms/step | loss 19449.578
# | iter    449 | 27.57 ms/step | loss 377975.219
# | iter    450 | 21.90 ms/step | loss  621.078
# | iter    451 | 99.88 ms/step | loss 20243.199
# | iter    452 | 21.25 ms/step | loss 4316.271
# | iter    453 | 23.30 ms/step | loss 1496.557
# | iter    454 | 17.49 ms/step | loss 18739.053
# | iter    455 | 16.91 ms/step | loss 236220.578
# | iter    456 | 24.02 ms/step | loss  507.982
# | iter    457 | 19.82 ms/step | loss 1254.906
# | iter    458 | 16.68 ms/step | loss  491.835
# | iter    459 | 24.07 ms/step | loss 1702.376
# | iter    460 | 23.34 ms/step | loss 24149.832
# | iter    461 | 15.34 ms/step | loss  883.067
# | iter    462 | 99.80 ms/step | loss  748.422
# | iter    463 | 20.89 ms/step | loss  755.841
# | iter    464 | 16.66 ms/step | loss 32495.994
# | iter    465 | 16.95 ms/step | loss  371.270
# | iter    466 | 21.95 ms/step | loss 7787.711
# | iter    467 | 23.00 ms/step | loss 1230.214
# | iter    468 | 25.09 ms/step | loss 5365.717
# | iter    469 | 19.13 ms/step | loss  705.790
# | iter    470 | 25.75 ms/step | loss 189810.891
# | iter    471 | 21.48 ms/step | loss 1054.580
# | iter    472 | 97.18 ms/step | loss  877.715
# | iter    473 | 15.47 ms/step | loss 2930.909
# | iter    474 | 18.62 ms/step | loss  688.666
# | iter    475 | 25.03 ms/step | loss  466.745
# | iter    476 | 23.19 ms/step | loss 17349.496
# | iter    477 | 16.93 ms/step | loss 21966.711
# | iter    478 | 25.32 ms/step | loss 43406.605
# | iter    479 | 21.56 ms/step | loss  414.585
# | iter    480 | 16.81 ms/step | loss 8477.387
# | iter    481 | 92.02 ms/step | loss  530.908
# | iter    482 | 30.29 ms/step | loss  681.231
# | iter    483 | 17.00 ms/step | loss  394.177
# | iter    484 | 24.82 ms/step | loss 151424.969
# | iter    485 | 20.19 ms/step | loss 1048.034
# | iter    486 | 16.82 ms/step | loss 1532.007
# | iter    487 | 24.90 ms/step | loss  462.869
# | iter    488 | 18.52 ms/step | loss 3379.046
# | iter    489 | 91.19 ms/step | loss 1512.535
# | iter    490 | 20.85 ms/step | loss 13976.832
# | iter    491 | 23.93 ms/step | loss 1699.209
# | iter    492 | 24.64 ms/step | loss  896.640
# | iter    493 | 18.95 ms/step | loss  556.559
# | iter    494 | 23.22 ms/step | loss  416.251
# | iter    495 | 24.49 ms/step | loss 5315.858
# | iter    496 | 19.40 ms/step | loss  576.985
# | iter    497 | 99.07 ms/step | loss 221646.484
# | iter    498 | 27.64 ms/step | loss 1263.912
# | iter    499 | 22.51 ms/step | loss  475.127
# | iter    500 | 16.00 ms/step | loss 3754.997
# | iter    501 | 16.89 ms/step | loss 32164.316
# | iter    502 | 21.80 ms/step | loss 179444.375
# | iter    503 | 22.86 ms/step | loss  411.604
# | iter    504 | 25.64 ms/step | loss 1187.244
# | iter    505 | 21.90 ms/step | loss 16023.416
# | iter    506 | 101.86 ms/step | loss 101896.422
# | iter    507 | 25.43 ms/step | loss 2307.469
# | iter    508 | 25.29 ms/step | loss  476.574
# | iter    509 | 18.74 ms/step | loss  633.926
# | iter    510 | 28.73 ms/step | loss 31714.818
# | iter    511 | 17.28 ms/step | loss  510.220
# | iter    512 | 24.96 ms/step | loss 15053.284
# | iter    513 | 24.76 ms/step | loss 2954.393
# | iter    514 | 22.93 ms/step | loss  484.563
# | iter    515 | 24.50 ms/step | loss 4530.489
# | iter    516 | 92.75 ms/step | loss 73659.141
# | iter    517 | 20.73 ms/step | loss 2720.281
# | iter    518 | 24.49 ms/step | loss 54818.133
# | iter    519 | 21.52 ms/step | loss 1760.875
# | iter    520 | 18.53 ms/step | loss 1053.922
# | iter    521 | 18.79 ms/step | loss 6126.672
# | iter    522 | 22.13 ms/step | loss  589.917
# | iter    523 | 20.76 ms/step | loss  608.592
# | iter    524 | 28.24 ms/step | loss 32482.230
# | iter    525 | 17.79 ms/step | loss 2925.303
# | iter    526 | 20.44 ms/step | loss 1324.648
# | iter    527 | 100.17 ms/step | loss 20873.980
# | iter    528 | 25.87 ms/step | loss  517.277
# | iter    529 | 24.23 ms/step | loss 17166.721
# | iter    530 | 22.21 ms/step | loss 141286.578
# | iter    531 | 24.47 ms/step | loss 1986.899
# | iter    532 | 16.47 ms/step | loss  587.263
# | iter    533 | 21.11 ms/step | loss 6073.560
# | iter    534 | 24.08 ms/step | loss  445.186
# | iter    535 | 24.41 ms/step | loss 3312.738
# | iter    536 | 20.94 ms/step | loss 79675.891
# | iter    537 | 86.51 ms/step | loss 7259.834
# | iter    538 | 18.79 ms/step | loss  465.538
# | iter    539 | 16.61 ms/step | loss  367.021
# | iter    540 | 20.46 ms/step | loss 1900.233
# | iter    541 | 20.97 ms/step | loss 216848.578
# | iter    542 | 15.42 ms/step | loss 78922.805
# | iter    543 | 25.56 ms/step | loss  955.749
# | iter    544 | 20.60 ms/step | loss 1712.847
# | iter    545 | 18.93 ms/step | loss  785.868
# | iter    546 | 99.90 ms/step | loss 22328.834
# | iter    547 | 24.86 ms/step | loss  779.257
# | iter    548 | 25.69 ms/step | loss  656.980
# | iter    549 | 25.24 ms/step | loss 51814.715
# | iter    550 | 22.98 ms/step | loss 1141.172
# | iter    551 | 23.64 ms/step | loss  815.837
# | iter    552 | 26.25 ms/step | loss  819.843
# | iter    553 | 24.38 ms/step | loss 9879.899
# | iter    554 | 91.42 ms/step | loss 5462.254
# | iter    555 | 24.35 ms/step | loss 12960.032
# | iter    556 | 20.81 ms/step | loss  692.013
# | iter    557 | 25.97 ms/step | loss 1819.131
# | iter    558 | 28.66 ms/step | loss 56460.820
# | iter    559 | 22.48 ms/step | loss  883.794
# | iter    560 | 22.83 ms/step | loss 1232.617
# | iter    561 | 21.17 ms/step | loss  459.342
# | iter    562 | 24.87 ms/step | loss 94036.844
# | iter    563 | 95.81 ms/step | loss 1335.683
# | iter    564 | 24.00 ms/step | loss  974.984
# | iter    565 | 19.79 ms/step | loss  410.158
# | iter    566 | 26.84 ms/step | loss 1213.194
# | iter    567 | 27.56 ms/step | loss  538.022
# | iter    568 | 18.60 ms/step | loss 347878.312
# | iter    569 | 19.72 ms/step | loss  610.689
# | iter    570 | 27.35 ms/step | loss 20498.385
# | iter    571 | 19.36 ms/step | loss  564.987
# | iter    572 | 22.09 ms/step | loss 1064.260
# | iter    573 | 24.34 ms/step | loss  518.931
# | iter    574 | 93.53 ms/step | loss 3641.463
# | iter    575 | 22.30 ms/step | loss 6502.376
# | iter    576 | 16.19 ms/step | loss  793.082
# | iter    577 | 23.38 ms/step | loss  572.233
# | iter    578 | 25.98 ms/step | loss 2102.699
# | iter    579 | 24.73 ms/step | loss  570.289
# | iter    580 | 20.76 ms/step | loss 1522.026
# | iter    581 | 19.97 ms/step | loss 279702.188
# | iter    582 | 25.09 ms/step | loss 1110.984
# | iter    583 | 100.10 ms/step | loss  371.667
# | iter    584 | 26.63 ms/step | loss 2990.235
# | iter    585 | 25.07 ms/step | loss 19438.016
# | iter    586 | 19.53 ms/step | loss 3712.812
# | iter    587 | 21.55 ms/step | loss 21687.189
# | iter    588 | 24.55 ms/step | loss 1086.372
# | iter    589 | 25.34 ms/step | loss  732.955
# | iter    590 | 22.52 ms/step | loss  470.104
# | iter    591 | 27.10 ms/step | loss  737.858
# | iter    592 | 102.41 ms/step | loss 2329.813
# | iter    593 | 19.05 ms/step | loss 1434.442
# | iter    594 | 25.04 ms/step | loss 54258.004
# | iter    595 | 20.07 ms/step | loss 18258.080
# | iter    596 | 32.55 ms/step | loss  987.702
# | iter    597 | 20.91 ms/step | loss  751.973
# | iter    598 | 16.77 ms/step | loss  748.273
# | iter    599 | 25.38 ms/step | loss 129332.539
# | iter    600 | 21.07 ms/step | loss 2887.384
# | iter    601 | 100.33 ms/step | loss 24112.967
# | iter    602 | 17.67 ms/step | loss  683.622
# | iter    603 | 21.15 ms/step | loss  873.909
# | iter    604 | 25.26 ms/step | loss 18729.352
# | iter    605 | 25.71 ms/step | loss 10929.611
# | iter    606 | 49.54 ms/step | loss 1300.146
# | iter    607 | 24.52 ms/step | loss 35057.082
# | iter    608 | 20.80 ms/step | loss  360.697
# | iter    609 | 24.29 ms/step | loss 2233.969
# | iter    610 | 95.76 ms/step | loss 6571.686
# | iter    611 | 17.09 ms/step | loss  454.422
# | iter    612 | 26.42 ms/step | loss 201551.594
# | iter    613 | 19.40 ms/step | loss  413.706
# | iter    614 | 22.71 ms/step | loss 2663.012
# | iter    615 | 25.11 ms/step | loss 1131.293
# | iter    616 | 19.33 ms/step | loss 5058.486
# | iter    617 | 21.60 ms/step | loss  595.384
# | iter    618 | 25.10 ms/step | loss 16006.905
# | iter    619 | 17.17 ms/step | loss 228803.750
# | iter    620 | 91.54 ms/step | loss  724.832
# | iter    621 | 16.93 ms/step | loss  530.982
# | iter    622 | 23.06 ms/step | loss 223551.750
# | iter    623 | 24.37 ms/step | loss 1118.783
# | iter    624 | 25.06 ms/step | loss  495.001
# | iter    625 | 20.30 ms/step | loss 14911.352
# | iter    626 | 26.19 ms/step | loss 2589.798
# | iter    627 | 25.36 ms/step | loss 1199.470
# | iter    628 | 96.00 ms/step | loss  680.210
# | iter    629 | 16.72 ms/step | loss  681.299
# | iter    630 | 19.79 ms/step | loss  623.060
# | iter    631 | 26.63 ms/step | loss 1406.708
# | iter    632 | 25.57 ms/step | loss 2609.789
# | iter    633 | 25.90 ms/step | loss 43215.793
# | iter    634 | 22.78 ms/step | loss  996.068
# | iter    635 | 24.20 ms/step | loss 150492.062
# | iter    636 | 21.46 ms/step | loss  580.952
# | iter    637 | 20.54 ms/step | loss 9956.070
# | iter    638 | 91.90 ms/step | loss 20536.521
# | iter    639 | 22.13 ms/step | loss 48862.586
# | iter    640 | 26.33 ms/step | loss  574.396
# | iter    641 | 25.28 ms/step | loss  696.526
# | iter    642 | 21.76 ms/step | loss 199173.312
# | iter    643 | 25.29 ms/step | loss 8762.246
# | iter    644 | 24.51 ms/step | loss  918.092
# | iter    645 | 20.26 ms/step | loss  466.149
# | iter    646 | 25.87 ms/step | loss  940.613
# | iter    647 | 21.52 ms/step | loss  765.489
# | iter    648 | 95.80 ms/step | loss  542.255
# | iter    649 | 24.38 ms/step | loss 105446.688
# | iter    650 | 26.79 ms/step | loss  433.956
# | iter    651 | 30.31 ms/step | loss 12506.496
# | iter    652 | 15.37 ms/step | loss  591.492
# | iter    653 | 22.95 ms/step | loss 109151.312
# | iter    654 | 33.28 ms/step | loss  522.782
# | iter    655 | 21.29 ms/step | loss  701.454
# | iter    656 | 23.97 ms/step | loss 263881.250
# | iter    657 | 17.39 ms/step | loss 13702.803
# | iter    658 | 96.20 ms/step | loss 36977.137
# | iter    659 | 18.28 ms/step | loss 13512.570
# | iter    660 | 17.59 ms/step | loss  974.466
# | iter    661 | 20.51 ms/step | loss  973.081
# | iter    662 | 23.52 ms/step | loss 3340.804
# | iter    663 | 17.04 ms/step | loss  412.197
# | iter    664 | 21.24 ms/step | loss  903.774
# | iter    665 | 17.88 ms/step | loss 3712.378
# | iter    666 | 22.83 ms/step | loss  870.288
# | iter    667 | 90.10 ms/step | loss 308376.344
# | iter    668 | 23.71 ms/step | loss 15530.441
# | iter    669 | 25.61 ms/step | loss 1729.614
# | iter    670 | 25.79 ms/step | loss  936.437
# | iter    671 | 19.43 ms/step | loss 74823.562
# | iter    672 | 20.83 ms/step | loss 2015.944
# | iter    673 | 17.41 ms/step | loss  841.708
# | iter    674 | 19.54 ms/step | loss  515.359
# | iter    675 | 20.82 ms/step | loss 310836.531
# | iter    676 | 20.88 ms/step | loss 1490.336
# | iter    677 | 99.58 ms/step | loss 4055.284
# | iter    678 | 16.37 ms/step | loss 1969.762
# | iter    679 | 23.20 ms/step | loss 1461.989
# | iter    680 | 22.82 ms/step | loss  413.008
# | iter    681 | 18.60 ms/step | loss 89729.438
# | iter    682 | 20.83 ms/step | loss 155959.844
# | iter    683 | 25.51 ms/step | loss 17574.248
# | iter    684 | 20.16 ms/step | loss  663.532
# | iter    685 | 94.95 ms/step | loss  669.452
# | iter    686 | 23.46 ms/step | loss  977.874
# | iter    687 | 26.04 ms/step | loss 1267.104
# | iter    688 | 28.28 ms/step | loss  417.793
# | iter    689 | 17.71 ms/step | loss 3898.486
# | iter    690 | 27.41 ms/step | loss  567.397
# | iter    691 | 25.31 ms/step | loss 3236.039
# | iter    692 | 21.68 ms/step | loss  391.169
# | iter    693 | 19.88 ms/step | loss 315150.094
# | iter    694 | 25.47 ms/step | loss  484.961
# | iter    695 | 94.20 ms/step | loss  409.244
# | iter    696 | 25.02 ms/step | loss 26361.648
# | iter    697 | 18.41 ms/step | loss 9138.744
# | iter    698 | 23.18 ms/step | loss 1220.872
# | iter    699 | 25.31 ms/step | loss 33509.395
# | iter    700 | 18.45 ms/step | loss 1926.675
# | iter    701 | 22.40 ms/step | loss  374.062
# | iter    702 | 25.14 ms/step | loss 10038.275
# | iter    703 | 21.06 ms/step | loss  867.801
# | iter    704 | 109.45 ms/step | loss 9356.892
# | iter    705 | 26.51 ms/step | loss  878.665
# | iter    706 | 29.42 ms/step | loss  489.415
# | iter    707 | 22.73 ms/step | loss  740.879
# | iter    708 | 23.44 ms/step | loss 4045.866
# | iter    709 | 25.14 ms/step | loss 1145.205
# | iter    710 | 24.38 ms/step | loss 1071.968
# | iter    711 | 25.83 ms/step | loss 25964.461
# | iter    712 | 24.26 ms/step | loss  503.691
# | iter    713 | 21.07 ms/step | loss 11122.809
# | iter    714 | 23.39 ms/step | loss  612.224
# | iter    715 | 88.89 ms/step | loss 1712.920
# | iter    716 | 16.91 ms/step | loss  863.658
# | iter    717 | 20.29 ms/step | loss 120304.164
# | iter    718 | 26.62 ms/step | loss 21168.223
# | iter    719 | 18.95 ms/step | loss 1841.292
# | iter    720 | 22.44 ms/step | loss  420.590
# | iter    721 | 15.24 ms/step | loss 11676.095
# | iter    722 | 17.83 ms/step | loss 13566.910
# | iter    723 | 22.72 ms/step | loss 1193.241
# | iter    724 | 14.89 ms/step | loss 4714.777
# | iter    725 | 94.02 ms/step | loss  854.554
# | iter    726 | 24.31 ms/step | loss 10959.998
# | iter    727 | 23.66 ms/step | loss  600.379
# | iter    728 | 24.85 ms/step | loss  524.448
# | iter    729 | 26.45 ms/step | loss  849.149
# | iter    730 | 23.22 ms/step | loss  288.035
# | iter    731 | 25.41 ms/step | loss 80782.922
# | iter    732 | 25.08 ms/step | loss 1569.445
# | iter    733 | 25.38 ms/step | loss  435.321
# | iter    734 | 108.82 ms/step | loss 2144.677
# | iter    735 | 17.12 ms/step | loss  491.378
# | iter    736 | 23.59 ms/step | loss 26081.832
# | iter    737 | 16.78 ms/step | loss  907.709
# | iter    738 | 18.75 ms/step | loss 28775.670
# | iter    739 | 26.01 ms/step | loss  557.095
# | iter    740 | 25.36 ms/step | loss 1465.800
# | iter    741 | 18.45 ms/step | loss  314.741
# | iter    742 | 99.78 ms/step | loss 28176.035
# | iter    743 | 22.76 ms/step | loss  553.639
# | iter    744 | 21.08 ms/step | loss 4534.357
# | iter    745 | 16.07 ms/step | loss  272.152
# | iter    746 | 33.87 ms/step | loss 5033.746
# | iter    747 | 21.11 ms/step | loss  838.751
# | iter    748 | 21.82 ms/step | loss 19936.639
# | iter    749 | 17.01 ms/step | loss 1205.748
# | iter    750 | 29.87 ms/step | loss 5497.256
# | iter    751 | 100.87 ms/step | loss  278.717
# | iter    752 | 25.93 ms/step | loss  656.042
# | iter    753 | 24.28 ms/step | loss 3193.571
# | iter    754 | 29.14 ms/step | loss 1707.992
# | iter    755 | 25.05 ms/step | loss  939.042
# | iter    756 | 21.79 ms/step | loss 94536.289
# | iter    757 | 22.96 ms/step | loss 1608.210
# | iter    758 | 39.15 ms/step | loss  397.668
# | iter    759 | 14.89 ms/step | loss 11825.271
# | iter    760 | 15.63 ms/step | loss  927.252
# | iter    761 | 14.24 ms/step | loss 283637.406
# | iter    762 | 100.68 ms/step | loss  529.489
# | iter    763 | 25.44 ms/step | loss 1782.568
# | iter    764 | 25.63 ms/step | loss 69324.547
# | iter    765 | 24.99 ms/step | loss 1483.198
# | iter    766 | 22.42 ms/step | loss 14865.234
# | iter    767 | 25.09 ms/step | loss  684.337
# | iter    768 | 31.34 ms/step | loss 143080.547
# | iter    769 | 23.14 ms/step | loss  428.233
# | iter    770 | 25.19 ms/step | loss 134204.859
# | iter    771 | 116.31 ms/step | loss 3424.021
# | iter    772 | 34.21 ms/step | loss  481.879
# | iter    773 | 26.01 ms/step | loss 2011.944
# | iter    774 | 17.20 ms/step | loss 1925.400
# | iter    775 | 21.57 ms/step | loss  668.225
# | iter    776 | 25.01 ms/step | loss 102593.508
# | iter    777 | 25.73 ms/step | loss 4285.150
# | iter    778 | 25.25 ms/step | loss  750.837
# | iter    779 | 33.36 ms/step | loss  977.202
# | iter    780 | 108.41 ms/step | loss  724.043
# | iter    781 | 25.15 ms/step | loss 23421.654
# | iter    782 | 25.15 ms/step | loss 3404.381
# | iter    783 | 25.28 ms/step | loss  702.711
# | iter    784 | 26.68 ms/step | loss 1984.139
# | iter    785 | 23.88 ms/step | loss  769.115
# | iter    786 | 24.64 ms/step | loss 1831.288
# | iter    787 | 25.42 ms/step | loss 4687.595
# | iter    788 | 25.20 ms/step | loss  326.826
# | iter    789 | 109.72 ms/step | loss 3686.057
# | iter    790 | 31.00 ms/step | loss  778.138
# | iter    791 | 22.32 ms/step | loss 43472.430
# | iter    792 | 25.75 ms/step | loss 1149.311
# | iter    793 | 26.82 ms/step | loss 5693.412
# | iter    794 | 24.80 ms/step | loss 12911.241
# | iter    795 | 24.89 ms/step | loss  498.659
# | iter    796 | 22.64 ms/step | loss 17320.629
# | iter    797 | 24.94 ms/step | loss 1698.657
# | iter    798 | 111.32 ms/step | loss 2247.474
# | iter    799 | 22.28 ms/step | loss 2496.538
# | iter    800 | 25.90 ms/step | loss  675.486
# | iter    801 | 25.03 ms/step | loss  305.210
# | iter    802 | 31.70 ms/step | loss 1880.085
# | iter    803 | 24.87 ms/step | loss 14696.477
# | iter    804 | 24.82 ms/step | loss  883.547
# | iter    805 | 25.31 ms/step | loss 348298.406
# | iter    806 | 27.68 ms/step | loss 11559.765
# | iter    807 | 16.65 ms/step | loss 2965.006
# | iter    808 | 96.42 ms/step | loss  319.521
# | iter    809 | 22.18 ms/step | loss  564.711
# | iter    810 | 24.32 ms/step | loss 10855.903
# | iter    811 | 27.94 ms/step | loss 268148.062
# | iter    812 | 15.93 ms/step | loss  661.417
# | iter    813 | 22.73 ms/step | loss 1069.296
# | iter    814 | 30.61 ms/step | loss  400.905
# | iter    815 | 15.62 ms/step | loss 2683.630
# | iter    816 | 33.90 ms/step | loss 2797.896
# | iter    817 | 31.26 ms/step | loss  707.106
# | iter    818 | 102.15 ms/step | loss 7105.490
# | iter    819 | 31.25 ms/step | loss 111176.312
# | iter    820 | 36.73 ms/step | loss  580.900
# | iter    821 | 15.63 ms/step | loss  498.422
# | iter    822 | 15.64 ms/step | loss  433.311
# | iter    823 | 24.51 ms/step | loss  548.389
# | iter    824 | 15.64 ms/step | loss  638.957
# | iter    825 | 15.63 ms/step | loss 262446.406
# | iter    826 | 25.43 ms/step | loss 3491.559
# | iter    827 | 17.79 ms/step | loss  767.476
# | iter    828 | 86.83 ms/step | loss 24202.736
# | iter    829 | 15.63 ms/step | loss  617.759
# | iter    830 | 22.91 ms/step | loss 1195.212
# | iter    831 | 30.22 ms/step | loss 39610.898
# | iter    832 | 33.59 ms/step | loss 1342.774
# | iter    833 | 28.65 ms/step | loss 1232.359
# | iter    834 | 31.26 ms/step | loss 312975.688
# | iter    835 | 16.66 ms/step | loss  433.533
# | iter    836 | 21.68 ms/step | loss 3359.846
# | iter    837 | 15.62 ms/step | loss  682.791
# | iter    838 | 100.28 ms/step | loss 1241.719
# | iter    839 | 15.62 ms/step | loss  683.317
# | iter    840 | 33.74 ms/step | loss 34311.684
# | iter    841 | 15.64 ms/step | loss  349.636
# | iter    842 | 23.49 ms/step | loss  335.889
# | iter    843 | 19.44 ms/step | loss 1338.973
# | iter    844 | 12.19 ms/step | loss 12265.101
# | iter    845 | 15.64 ms/step | loss  859.740
# | iter    846 | 15.63 ms/step | loss  419.583
# | iter    847 | 96.97 ms/step | loss 1005.596
# | iter    848 | 15.21 ms/step | loss  692.125
# | iter    849 | 10.01 ms/step | loss 15896.336
# | iter    850 | 15.63 ms/step | loss  533.240
# | iter    851 | 15.63 ms/step | loss  602.306
# | iter    852 | 15.63 ms/step | loss 69668.844
# | iter    853 | 15.63 ms/step | loss 2675.770
# | iter    854 | 19.59 ms/step | loss  419.805
# | iter    855 | 23.19 ms/step | loss 1134.236
# | iter    856 | 15.63 ms/step | loss  824.338
# | iter    857 | 92.11 ms/step | loss 97083.305
# | iter    858 | 29.10 ms/step | loss  340.062
# | iter    859 | 15.86 ms/step | loss 3818.507
# | iter    860 | 31.70 ms/step | loss 52792.668
# | iter    861 | 21.42 ms/step | loss  602.243
# | iter    862 | 31.26 ms/step | loss  632.693
# | iter    863 | 15.62 ms/step | loss  937.108
# | iter    864 | 20.99 ms/step | loss 3837.438
# | iter    865 | 92.31 ms/step | loss 57314.488
# | iter    866 | 22.15 ms/step | loss 26612.980
# | iter    867 | 31.27 ms/step | loss 1122.441
# | iter    868 | 23.92 ms/step | loss 1877.222
# | iter    869 | 31.25 ms/step | loss 4828.625
# | iter    870 | 31.25 ms/step | loss 77601.664
# | iter    871 | 24.60 ms/step | loss  596.988
# | iter    872 | 27.13 ms/step | loss  538.707
# | iter    873 | 15.64 ms/step | loss 5209.941
# | iter    874 | 12.69 ms/step | loss  850.613
# | iter    875 | 96.91 ms/step | loss 40443.316
# | iter    876 | 31.31 ms/step | loss 3884.223
# | iter    877 | 15.64 ms/step | loss  659.824
# | iter    878 | 15.63 ms/step | loss 159531.594
# | iter    879 | 12.07 ms/step | loss  516.623
# | iter    880 | 15.64 ms/step | loss 1871.087
# | iter    881 | 15.64 ms/step | loss 2037.280
# | iter    882 | 22.48 ms/step | loss 1096.662
# | iter    883 | 31.25 ms/step | loss  713.995
# | iter    884 | 87.38 ms/step | loss 22035.719
# | iter    885 | 22.32 ms/step | loss 211195.156
# | iter    886 | 20.06 ms/step | loss  588.960
# | iter    887 | 31.25 ms/step | loss  729.521
# | iter    888 | 15.62 ms/step | loss 78969.789
# | iter    889 | 18.12 ms/step | loss 12705.762
# | iter    890 | 22.96 ms/step | loss  584.059
# | iter    891 | 15.62 ms/step | loss 1345.536
# | iter    892 | 11.83 ms/step | loss  806.147
# | iter    893 | 31.73 ms/step | loss 10992.281
# | iter    894 |  8.39 ms/step | loss 1376.634
# | iter    895 | 99.52 ms/step | loss 289908.531
# | iter    896 | 15.24 ms/step | loss  413.284
# | iter    897 | 29.41 ms/step | loss  751.122
# | iter    898 | 16.34 ms/step | loss 2500.285
# | iter    899 | 21.21 ms/step | loss  712.158
# | iter    900 | 15.63 ms/step | loss 1838.399
# | iter    901 | 15.61 ms/step | loss 227085.531
# | iter    902 |  8.20 ms/step | loss  961.652
# | iter    903 | 15.63 ms/step | loss  311.462
# | iter    904 | 16.81 ms/step | loss 20779.768
# | iter    905 | 94.77 ms/step | loss 4218.729
# | iter    906 | 31.25 ms/step | loss 246258.531
# | iter    907 | 15.63 ms/step | loss 1436.878
# | iter    908 | 31.25 ms/step | loss 2784.330
# | iter    909 | 35.66 ms/step | loss  981.319
# | iter    910 | 15.62 ms/step | loss 1212.508
# | iter    911 | 23.68 ms/step | loss 43991.441
# | iter    912 | 15.62 ms/step | loss 13849.337
# | iter    913 | 15.63 ms/step | loss 1176.438
# | iter    914 | 97.62 ms/step | loss 216562.781
# | iter    915 | 21.50 ms/step | loss  833.572
# | iter    916 | 31.25 ms/step | loss  531.138
# | iter    917 | 15.63 ms/step | loss 1127.312
# | iter    918 | 31.26 ms/step | loss 6024.105
# | iter    919 | 15.66 ms/step | loss  561.595
# | iter    920 | 20.42 ms/step | loss 169531.109
# | iter    921 | 31.26 ms/step | loss  752.641
# | iter    922 | 104.26 ms/step | loss 3145.544
# | iter    923 | 31.25 ms/step | loss  533.213
# | iter    924 | 27.05 ms/step | loss  862.008
# | iter    925 | 15.63 ms/step | loss 5033.982
# | iter    926 | 16.98 ms/step | loss  641.380
# | iter    927 | 21.80 ms/step | loss 5444.117
# | iter    928 | 28.30 ms/step | loss 58853.352
# | iter    929 | 31.26 ms/step | loss  306.191
# | iter    930 | 28.35 ms/step | loss 1423.213
# | iter    931 | 93.24 ms/step | loss  596.413
# | iter    932 | 17.47 ms/step | loss  455.108
# | iter    933 | 15.64 ms/step | loss  782.523
# | iter    934 | 22.07 ms/step | loss 18513.875
# | iter    935 | 31.25 ms/step | loss 1116.180
# | iter    936 | 15.64 ms/step | loss  757.224
# | iter    937 | 22.86 ms/step | loss 18514.422
# | iter    938 | 31.25 ms/step | loss  260.384
# | iter    939 | 21.32 ms/step | loss 19429.945
# | iter    940 | 33.01 ms/step | loss 47764.848
# | iter    941 | 24.85 ms/step | loss 1011.317
# | iter    942 | 98.81 ms/step | loss 1477.941
# | iter    943 | 15.63 ms/step | loss  407.159
# | iter    944 | 18.77 ms/step | loss  671.905
# | iter    945 | 15.63 ms/step | loss  287.721
# | iter    946 | 15.63 ms/step | loss 1192.678
# | iter    947 | 24.98 ms/step | loss 2011.735
# | iter    948 | 12.94 ms/step | loss 55117.383
# | iter    949 | 15.64 ms/step | loss  334.345
# | iter    950 | 15.63 ms/step | loss 332882.125
# | iter    951 | 87.97 ms/step | loss  739.357
# | iter    952 | 15.63 ms/step | loss  364.305
# | iter    953 | 19.62 ms/step | loss  708.809
# | iter    954 | 15.64 ms/step | loss  661.383
# | iter    955 | 17.84 ms/step | loss 1822.506
# | iter    956 | 19.90 ms/step | loss 7787.534
# | iter    957 | 31.25 ms/step | loss  372.148
# | iter    958 | 22.81 ms/step | loss  464.379
# | iter    959 | 15.63 ms/step | loss 2150.085
# | iter    960 | 98.43 ms/step | loss 52421.918
# | iter    961 | 21.40 ms/step | loss 1703.782
# | iter    962 | 35.89 ms/step | loss  733.108
# | iter    963 | 15.63 ms/step | loss 13731.214
# | iter    964 | 15.62 ms/step | loss 1072.744
# | iter    965 | 22.22 ms/step | loss  320.357
# | iter    966 | 27.31 ms/step | loss 1181.877
# | iter    967 | 24.17 ms/step | loss  628.121
# | iter    968 | 33.14 ms/step | loss 2145.398
# | iter    969 | 115.90 ms/step | loss 2994.596
# | iter    970 | 33.10 ms/step | loss 10146.761
# | iter    971 | 32.96 ms/step | loss 1702.276
# | iter    972 | 24.87 ms/step | loss  378.453
# | iter    973 | 24.78 ms/step | loss  891.309
# | iter    974 | 17.03 ms/step | loss 14414.949
# | iter    975 | 24.60 ms/step | loss  952.235
# | iter    976 | 25.04 ms/step | loss  306.663
# | iter    977 | 24.84 ms/step | loss 5538.626
# | iter    978 | 116.85 ms/step | loss 140645.828
# | iter    979 | 25.21 ms/step | loss  635.687
# | iter    980 | 24.99 ms/step | loss 1640.182
# | iter    981 | 28.93 ms/step | loss  960.026
# | iter    982 | 33.33 ms/step | loss  485.883
# | iter    983 | 16.81 ms/step | loss 4151.002
# | iter    984 | 25.34 ms/step | loss  563.097
# | iter    985 | 25.08 ms/step | loss 7346.106
# | iter    986 | 24.92 ms/step | loss 2291.036
# | iter    987 | 25.28 ms/step | loss 1365.596
# | iter    988 | 124.74 ms/step | loss 9466.987
# | iter    989 | 24.18 ms/step | loss 1195.493
# | iter    990 | 33.58 ms/step | loss 6691.561
# | iter    991 | 26.04 ms/step | loss  770.813
# | iter    992 | 30.90 ms/step | loss 10701.102
# | iter    993 | 24.34 ms/step | loss  597.513
# | iter    994 | 33.67 ms/step | loss 25094.939
# | iter    995 | 32.97 ms/step | loss  339.946
# | iter    996 | 30.98 ms/step | loss 1606.535
# | iter    997 | 26.58 ms/step | loss  735.882
# | iter    998 | 117.52 ms/step | loss 43444.016
# | iter    999 | 17.54 ms/step | loss 1920.361
# | iter   1000 | 23.30 ms/step | loss  959.391
# | iter   1001 | 25.19 ms/step | loss  790.703
# | iter   1002 | 33.42 ms/step | loss  521.978
# | iter   1003 | 24.32 ms/step | loss 3719.506
# | iter   1004 | 25.55 ms/step | loss 36522.250
# | iter   1005 | 17.16 ms/step | loss  384.596
# | iter   1006 | 31.24 ms/step | loss  525.742
# | iter   1007 | 33.74 ms/step | loss 13449.807
# | iter   1008 | 171.87 ms/step | loss  367.058
# | iter   1009 | 16.44 ms/step | loss  923.408
# | iter   1010 | 24.92 ms/step | loss 1231.615
# | iter   1011 | 17.40 ms/step | loss  510.825
# | iter   1012 | 16.44 ms/step | loss  912.034
# | iter   1013 | 24.90 ms/step | loss 26489.336
# ...
# | iter   2864 | 24.69 ms/step | loss  326.309
# | iter   2865 | 21.77 ms/step | loss 24154.807
# | iter   2866 | 18.49 ms/step | loss  248.780
# | iter   2867 | 25.33 ms/step | loss 2647.271
# | iter   2868 | 20.80 ms/step | loss  636.532
# | iter   2869 | 20.84 ms/step | loss  554.525
# | iter   2870 | 27.55 ms/step | loss 24122.404
# | iter   2871 | 24.24 ms/step | loss 1068.516
# | iter   2872 | 17.41 ms/step | loss  308.099
# | iter   2873 | 99.60 ms/step | loss  795.138
# | iter   2874 | 16.59 ms/step | loss 1311.008
# | iter   2875 | 23.17 ms/step | loss  730.058
# | iter   2876 | 19.90 ms/step | loss 1325.411
# | iter   2877 | 25.33 ms/step | loss 40609.070
# | iter   2878 | 20.76 ms/step | loss  528.089
# | iter   2879 | 17.45 ms/step | loss 1533.246
# | iter   2880 | 23.10 ms/step | loss  289.176
# | iter   2881 | 20.92 ms/step | loss  689.273
# | iter   2882 | 96.77 ms/step | loss 64422.016
# | iter   2883 | 20.70 ms/step | loss  872.907
# | iter   2884 | 24.73 ms/step | loss 1531.596
# | iter   2885 | 21.12 ms/step | loss  449.761
# | iter   2886 | 25.39 ms/step | loss 17785.639
# | iter   2887 | 18.39 ms/step | loss 75464.977
# | iter   2888 | 22.01 ms/step | loss 2017.496
# | iter   2889 | 16.12 ms/step | loss  636.404
# | iter   2890 | 98.82 ms/step | loss 79159.266
# | iter   2891 | 21.34 ms/step | loss 1091.589
# | iter   2892 | 19.63 ms/step | loss  787.160
# | iter   2893 | 20.18 ms/step | loss  891.072
# | iter   2894 | 28.75 ms/step | loss 2444.733
# | iter   2895 |  8.12 ms/step | loss  814.626
# | iter   2896 | 20.92 ms/step | loss  334.161
# | iter   2897 | 20.50 ms/step | loss  448.298
# | iter   2898 | 24.33 ms/step | loss 35161.238
# | iter   2899 | 97.94 ms/step | loss 1564.574
# | iter   2900 | 15.98 ms/step | loss  234.170
# | iter   2901 | 16.55 ms/step | loss  415.499
# | iter   2902 | 22.31 ms/step | loss 1975.797
# | iter   2903 | 25.47 ms/step | loss 12167.106
# | iter   2904 | 19.06 ms/step | loss  210.695
# | iter   2905 | 25.12 ms/step | loss 168079.578
# | iter   2906 | 24.98 ms/step | loss 2071.955
# | iter   2907 | 20.39 ms/step | loss  719.478
# | iter   2908 | 16.28 ms/step | loss  421.201
# | iter   2909 | 21.12 ms/step | loss  334.637
# | iter   2910 | 93.65 ms/step | loss 1152.928
# | iter   2911 | 24.81 ms/step | loss 40795.785
# | iter   2912 | 22.09 ms/step | loss 1796.111
# | iter   2913 | 25.88 ms/step | loss 1566.979
# | iter   2914 | 14.58 ms/step | loss 1363.802
# | iter   2915 | 21.68 ms/step | loss 133460.750
# | iter   2916 | 24.74 ms/step | loss  842.585
# | iter   2917 | 16.70 ms/step | loss 14862.550
# | iter   2918 | 25.36 ms/step | loss 67856.430
# | iter   2919 | 90.27 ms/step | loss  780.687
# | iter   2920 | 20.76 ms/step | loss  739.559
# | iter   2921 | 21.34 ms/step | loss  377.780
# | iter   2922 | 18.82 ms/step | loss 8863.907
# | iter   2923 | 22.61 ms/step | loss  385.504
# | iter   2924 | 23.10 ms/step | loss 1479.716
# | iter   2925 | 24.45 ms/step | loss 112315.102
# | iter   2926 | 20.82 ms/step | loss 283894.031
# | iter   2927 | 16.10 ms/step | loss  234.980
# | iter   2928 | 96.13 ms/step | loss 12741.521
# | iter   2929 | 16.18 ms/step | loss  897.186
# | iter   2930 | 18.65 ms/step | loss 1011.241
# | iter   2931 | 20.91 ms/step | loss  710.782
# | iter   2932 | 17.62 ms/step | loss  501.736
# | iter   2933 | 17.62 ms/step | loss 66414.734
# | iter   2934 | 22.17 ms/step | loss  588.491
# | iter   2935 | 27.44 ms/step | loss 1121.423
# | iter   2936 | 22.54 ms/step | loss 8955.718
# | iter   2937 | 95.41 ms/step | loss 210117.016
# | iter   2938 | 25.75 ms/step | loss 2789.388
# | iter   2939 | 20.42 ms/step | loss 3819.856
# | iter   2940 | 24.31 ms/step | loss 42529.695
# | iter   2941 | 13.98 ms/step | loss  250.077
# | iter   2942 | 17.46 ms/step | loss 7690.009
# | iter   2943 | 22.39 ms/step | loss  458.830
# | iter   2944 | 15.09 ms/step | loss 7753.645
# | iter   2945 | 25.70 ms/step | loss  687.714
# | iter   2946 | 99.45 ms/step | loss 16831.330
# | iter   2947 | 21.91 ms/step | loss  398.164
# | iter   2948 | 25.26 ms/step | loss 14117.568
# | iter   2949 | 75.27 ms/step | loss 1383.245
# | iter   2950 | 19.30 ms/step | loss 1029.725
# | iter   2951 | 21.14 ms/step | loss  730.712
# | iter   2952 | 23.85 ms/step | loss 6260.442
# | iter   2953 | 14.28 ms/step | loss 62958.672
# | iter   2954 | 22.06 ms/step | loss  364.166
# | iter   2955 | 16.07 ms/step | loss 37428.348
# | iter   2956 | 99.80 ms/step | loss  863.872
# | iter   2957 | 20.84 ms/step | loss  530.756
# | iter   2958 | 24.40 ms/step | loss 5405.580
# | iter   2959 | 24.82 ms/step | loss  520.966
# | iter   2960 | 25.53 ms/step | loss  685.977
# | iter   2961 | 24.21 ms/step | loss 10297.196
# | iter   2962 | 22.04 ms/step | loss 1629.489
# | iter   2963 | 22.48 ms/step | loss  916.410
# | iter   2964 | 26.30 ms/step | loss 30473.260
# | iter   2965 | 24.28 ms/step | loss 5808.658
# | iter   2966 | 91.50 ms/step | loss 13096.305
# | iter   2967 | 17.26 ms/step | loss  637.289
# | iter   2968 | 22.00 ms/step | loss  919.485
# | iter   2969 | 16.20 ms/step | loss 1224.737
# | iter   2970 | 25.33 ms/step | loss  514.639
# | iter   2971 | 21.80 ms/step | loss  191.318
# | iter   2972 | 16.65 ms/step | loss 3769.573
# | iter   2973 | 16.87 ms/step | loss 174595.625
# | iter   2974 | 26.95 ms/step | loss 77157.703
# | iter   2975 | 19.32 ms/step | loss 1226.013
# | iter   2976 | 91.07 ms/step | loss  940.939
# | iter   2977 | 15.75 ms/step | loss  690.581
# | iter   2978 | 21.14 ms/step | loss  742.177
# | iter   2979 | 27.86 ms/step | loss  581.148
# | iter   2980 | 24.89 ms/step | loss 16335.859
# | iter   2981 | 19.41 ms/step | loss  841.321
# | iter   2982 | 13.23 ms/step | loss 1022.164
# | iter   2983 | 22.04 ms/step | loss  852.633
# | iter   2984 | 21.38 ms/step | loss  837.742
# | iter   2985 | 17.38 ms/step | loss 9160.032
# | iter   2986 | 99.90 ms/step | loss 36580.359
# | iter   2987 | 17.66 ms/step | loss  254.850
# | iter   2988 | 22.35 ms/step | loss 6622.900
# | iter   2989 | 16.11 ms/step | loss  451.724
# | iter   2990 | 25.12 ms/step | loss 1444.363
# | iter   2991 | 20.30 ms/step | loss 17754.479
# | iter   2992 | 26.04 ms/step | loss 6576.600
# | iter   2993 | 21.89 ms/step | loss  503.049
# | iter   2994 | 22.62 ms/step | loss 1035.234
# | iter   2995 | 99.90 ms/step | loss  646.988
# | iter   2996 | 22.06 ms/step | loss  493.714
# | iter   2997 | 24.46 ms/step | loss 74493.977
# | iter   2998 | 24.49 ms/step | loss   97.448
# | iter   2999 | 15.37 ms/step | loss 15111.248
# | iter   3000 | 24.67 ms/step | loss 1153.596
# | iter   3001 | 22.45 ms/step | loss 3089.675
# | iter   3002 | 25.77 ms/step | loss  634.156
# | iter   3003 | 17.10 ms/step | loss  496.374
# | iter   3004 | 22.13 ms/step | loss 1777.238
# | iter   3005 | 89.14 ms/step | loss 55566.336
# | iter   3006 | 26.71 ms/step | loss  705.970
# | iter   3007 | 17.00 ms/step | loss 24532.539
# | iter   3008 | 23.55 ms/step | loss 3159.958
# | iter   3009 | 16.01 ms/step | loss 1872.395
# | iter   3010 | 25.52 ms/step | loss  524.867
# | iter   3011 | 21.40 ms/step | loss 111322.867
# | iter   3012 | 16.87 ms/step | loss 4977.512
# | iter   3013 | 96.05 ms/step | loss  721.378
# | iter   3014 | 26.66 ms/step | loss 1787.190
# | iter   3015 | 19.41 ms/step | loss 7361.722
# | iter   3016 | 27.87 ms/step | loss 1596.893
# | iter   3017 | 29.32 ms/step | loss  537.495
# | iter   3018 | 23.49 ms/step | loss  299.024
# | iter   3019 | 24.88 ms/step | loss 3888.776
# | iter   3020 | 20.85 ms/step | loss 9098.392
# | iter   3021 | 16.84 ms/step | loss  499.998
# | iter   3022 | 97.36 ms/step | loss 25850.705
# | iter   3023 | 24.57 ms/step | loss 1071.902
# | iter   3024 | 24.16 ms/step | loss  276.502
# | iter   3025 | 24.66 ms/step | loss  907.341
# | iter   3026 | 16.58 ms/step | loss 44928.555
# | iter   3027 | 21.57 ms/step | loss  328.938
# | iter   3028 | 16.98 ms/step | loss 15660.507
# | iter   3029 | 14.52 ms/step | loss  350.381
# | iter   3030 | 25.42 ms/step | loss 75625.633
# | iter   3031 | 26.80 ms/step | loss  628.835
# | iter   3032 | 99.40 ms/step | loss  594.547
# | iter   3033 | 18.52 ms/step | loss 3746.829
# | iter   3034 | 16.79 ms/step | loss 75318.398
# | iter   3035 | 20.89 ms/step | loss  150.353
# | iter   3036 | 21.60 ms/step | loss  763.719
# | iter   3037 | 17.02 ms/step | loss  388.623
# | iter   3038 | 20.88 ms/step | loss 122353.633
# | iter   3039 | 21.72 ms/step | loss  720.149
# | iter   3040 | 16.44 ms/step | loss  313.734
# | iter   3041 | 19.87 ms/step | loss  501.271
# | iter   3042 | 19.72 ms/step | loss 6221.537
# | iter   3043 | 96.06 ms/step | loss 45176.203
# | iter   3044 | 15.10 ms/step | loss  350.683
# | iter   3045 | 16.52 ms/step | loss 1589.746
# | iter   3046 | 27.95 ms/step | loss 1809.834
# | iter   3047 | 21.03 ms/step | loss 2085.156
# | iter   3048 | 25.22 ms/step | loss  707.529
# | iter   3049 | 24.32 ms/step | loss 71041.594
# | iter   3050 | 17.23 ms/step | loss 13608.720
# | iter   3051 | 16.66 ms/step | loss 11774.273
# | iter   3052 | 23.55 ms/step | loss  435.624
# | iter   3053 | 88.44 ms/step | loss  967.804
# | iter   3054 | 25.63 ms/step | loss 5363.561
# | iter   3055 | 21.50 ms/step | loss 323290.875
# | iter   3056 | 14.49 ms/step | loss  499.319
# | iter   3057 | 20.14 ms/step | loss 1175.774
# | iter   3058 | 29.50 ms/step | loss 1307.180
# | iter   3059 | 16.44 ms/step | loss  226.207
# | iter   3060 | 23.18 ms/step | loss 61545.719
# | iter   3061 | 20.83 ms/step | loss 1932.301
# | iter   3062 | 100.00 ms/step | loss 2826.608
# | iter   3063 | 20.61 ms/step | loss  148.758
# | iter   3064 | 17.69 ms/step | loss 273397.062
# | iter   3065 | 22.06 ms/step | loss  679.550
# | iter   3066 | 23.74 ms/step | loss 20448.553
# | iter   3067 | 20.94 ms/step | loss  606.976
# | iter   3068 | 24.94 ms/step | loss  814.906
# | iter   3069 | 19.17 ms/step | loss 12477.846
# | iter   3070 | 24.85 ms/step | loss 1056.839
# | iter   3071 | 100.02 ms/step | loss 23170.305
# | iter   3072 | 18.90 ms/step | loss  470.954
# | iter   3073 | 15.00 ms/step | loss  259.596
# | iter   3074 | 18.68 ms/step | loss  553.242
# | iter   3075 | 25.03 ms/step | loss 1130.083
# | iter   3076 | 22.94 ms/step | loss  917.001
# | iter   3077 | 24.33 ms/step | loss 16914.947
# | iter   3078 | 25.97 ms/step | loss 7539.165
# | iter   3079 | 30.28 ms/step | loss  890.299
# | iter   3080 | 24.45 ms/step | loss 17015.664
# | iter   3081 | 91.60 ms/step | loss  191.623
# | iter   3082 | 27.53 ms/step | loss  258.719
# | iter   3083 | 18.58 ms/step | loss  826.390
# | iter   3084 | 17.47 ms/step | loss 264362.438
# | iter   3085 | 19.78 ms/step | loss 4201.161
# | iter   3086 | 21.43 ms/step | loss  917.357
# | iter   3087 | 24.94 ms/step | loss  916.400
# | iter   3088 | 24.48 ms/step | loss 111512.984
# | iter   3089 | 95.87 ms/step | loss 6205.646
# | iter   3090 | 24.89 ms/step | loss 81675.500
# | iter   3091 | 21.64 ms/step | loss 2184.376
# | iter   3092 | 23.48 ms/step | loss  355.208
# | iter   3093 | 25.93 ms/step | loss  226.151
# | iter   3094 | 24.34 ms/step | loss 7416.699
# | iter   3095 | 22.14 ms/step | loss 17486.818
# | iter   3096 | 27.91 ms/step | loss 1571.384
# | iter   3097 | 21.05 ms/step | loss  159.944
# | iter   3098 | 20.94 ms/step | loss  593.870
# | iter   3099 | 97.01 ms/step | loss  707.765
# | iter   3100 | 16.31 ms/step | loss 4968.364
# | iter   3101 | 16.50 ms/step | loss  261.470
# | iter   3102 | 26.21 ms/step | loss 201408.031
# | iter   3103 | 21.26 ms/step | loss  953.700
# | iter   3104 | 22.37 ms/step | loss 1138.788
# | iter   3105 | 24.25 ms/step | loss  839.493
# | iter   3106 | 16.23 ms/step | loss 2143.382
# | iter   3107 | 16.64 ms/step | loss 220570.469
# | iter   3108 | 98.97 ms/step | loss 1570.054
# | iter   3109 | 23.09 ms/step | loss 1657.368
# | iter   3110 | 23.66 ms/step | loss  355.683
# | iter   3111 | 25.56 ms/step | loss  786.483
# | iter   3112 | 20.06 ms/step | loss 1210.633
# | iter   3113 | 23.27 ms/step | loss  904.577
# | iter   3114 | 29.87 ms/step | loss 343251.938
# | iter   3115 | 15.96 ms/step | loss 2704.021
# | iter   3116 | 24.74 ms/step | loss 1006.376
# | iter   3117 | 23.33 ms/step | loss  140.122
# | iter   3118 | 16.62 ms/step | loss 1288.673
# | iter   3119 | 96.04 ms/step | loss  574.391
# | iter   3120 | 24.54 ms/step | loss  226.337
# | iter   3121 | 20.32 ms/step | loss 272304.250
# | iter   3122 | 22.57 ms/step | loss 2229.926
# | iter   3123 | 15.74 ms/step | loss 261960.281
# | iter   3124 | 17.15 ms/step | loss  267.315
# | iter   3125 | 20.54 ms/step | loss 1434.287
# | iter   3126 | 19.94 ms/step | loss  594.413
# | iter   3127 | 17.30 ms/step | loss 7336.059
# | iter   3128 | 14.96 ms/step | loss 202584.016
# | iter   3129 | 89.14 ms/step | loss  611.367
# | iter   3130 | 22.17 ms/step | loss  510.079
# | iter   3131 | 24.77 ms/step | loss 7727.254
# | iter   3132 | 20.22 ms/step | loss  502.580
# | iter   3133 | 28.35 ms/step | loss 64584.250
# | iter   3134 | 25.19 ms/step | loss 1193.333
# | iter   3135 | 19.70 ms/step | loss 2168.107
# | iter   3136 | 26.45 ms/step | loss 1291.222
# | iter   3137 | 17.13 ms/step | loss  334.496
# | iter   3138 | 96.83 ms/step | loss  733.557
# | iter   3139 | 20.37 ms/step | loss 26464.084
# | iter   3140 | 19.00 ms/step | loss 8471.344
# | iter   3141 | 20.05 ms/step | loss 1093.688
# | iter   3142 | 16.81 ms/step | loss  446.621
# | iter   3143 | 23.09 ms/step | loss  730.622
# | iter   3144 | 21.37 ms/step | loss 14258.979
# | iter   3145 | 22.10 ms/step | loss  329.463
# | iter   3146 | 97.80 ms/step | loss  525.070
# | iter   3147 | 24.38 ms/step | loss 1271.006
# | iter   3148 | 24.71 ms/step | loss 2532.496
# | iter   3149 | 16.90 ms/step | loss 18885.869
# | iter   3150 | 17.97 ms/step | loss  581.184
# | iter   3151 | 32.88 ms/step | loss  542.393
# | iter   3152 | 24.25 ms/step | loss 74174.898
# | iter   3153 | 19.73 ms/step | loss  404.622
# | iter   3154 | 21.42 ms/step | loss 1053.181
# | iter   3155 | 99.39 ms/step | loss 102273.398
# | iter   3156 | 22.28 ms/step | loss  239.101
# | iter   3157 | 19.28 ms/step | loss  501.218
# | iter   3158 | 24.85 ms/step | loss  394.128
# | iter   3159 | 19.03 ms/step | loss 1569.187
# | iter   3160 | 18.29 ms/step | loss 21575.066
# | iter   3161 | 19.67 ms/step | loss 1900.653
# | iter   3162 | 22.34 ms/step | loss 14220.271
# | iter   3163 | 25.08 ms/step | loss  508.287
# | iter   3164 | 17.69 ms/step | loss 21238.061
# | iter   3165 | 16.98 ms/step | loss 1350.876
# | iter   3166 | 103.46 ms/step | loss 12481.737
# | iter   3167 | 21.99 ms/step | loss  359.390
# | iter   3168 | 17.69 ms/step | loss 244652.062
# | iter   3169 | 16.87 ms/step | loss 1010.119
# | iter   3170 | 21.92 ms/step | loss 16398.498
# | iter   3171 | 25.02 ms/step | loss  956.253
# | iter   3172 | 25.40 ms/step | loss  637.699
# | iter   3173 | 19.00 ms/step | loss 27578.936
# | iter   3174 | 23.46 ms/step | loss  186.934
# | iter   3175 | 99.80 ms/step | loss 76066.109
# | iter   3176 | 24.60 ms/step | loss 22076.721
# | iter   3177 | 19.41 ms/step | loss  714.532
# | iter   3178 | 24.96 ms/step | loss 3558.263
# | iter   3179 | 25.13 ms/step | loss 1009.168
# | iter   3180 | 20.45 ms/step | loss 1934.228
# | iter   3181 | 17.40 ms/step | loss  349.987
# | iter   3182 | 26.52 ms/step | loss 1705.057
# | iter   3183 | 19.99 ms/step | loss  302.257
# | iter   3184 | 100.15 ms/step | loss 173217.078
# | iter   3185 | 24.29 ms/step | loss 2616.502
# | iter   3186 | 21.67 ms/step | loss 2681.071
# | iter   3187 | 16.40 ms/step | loss  232.302
# | iter   3188 | 24.34 ms/step | loss  979.010
# | iter   3189 | 23.47 ms/step | loss 271680.781
# | iter   3190 | 25.24 ms/step | loss 285510.969
# | iter   3191 | 24.27 ms/step | loss  654.200
# | iter   3192 | 21.58 ms/step | loss 3206.715
# | iter   3193 | 87.23 ms/step | loss  541.434
# | iter   3194 | 22.59 ms/step | loss  538.384
# | iter   3195 | 23.50 ms/step | loss  412.266
# | iter   3196 | 24.56 ms/step | loss  906.051
# | iter   3197 | 21.05 ms/step | loss 53275.879
# | iter   3198 | 22.44 ms/step | loss  732.127
# | iter   3199 | 24.70 ms/step | loss 8968.053
# | iter   3200 | 22.14 ms/step | loss  550.044
# | iter   3201 | 24.38 ms/step | loss 24492.621

# %%
class WrappedModel(ModelWrapper):
    def forward(self, x: torch.Tensor, t: torch.Tensor, **extras):
        return self.model(x, t)

wrapped_vf = WrappedModel(vf)

# %%
# step size for ode solver
step_size = 0.05

norm = cm.colors.Normalize(vmax=50, vmin=0)

batch_size = 10000  # batch size
eps_time = 1e-2
T = torch.linspace(0,1,10)  # sample times
T = T.to(device=device)

x_init = torch.randn((batch_size, 2), dtype=torch.float32, device=device)
solver = ODESolver(velocity_model=wrapped_vf)  # create an ODESolver class
sol = solver.sample(time_grid=T, x_init=x_init, method='midpoint', step_size=step_size, return_intermediates=True)  # sample from the model

# %%
for i in range(10):
    # sol[i]=reverse_normalization(data2noiseTransform.inverse(torch.tensor(sol[i]).to(device))[0].detach().cpu())
    sol[i]=sol[i].to('cpu')
    # sol = sol.cpu().numpy()
T = T.cpu()
# sol[i].cpu()

# %%
(sol[9]).max()
# Out:
# tensor(60.9808, device='cuda:0')

# %%
#VISUALIZE PATH

RR=100
fig, axs = plt.subplots(1, 11,figsize=(20,20))

for i in range(11):
    # H= axs[i].hist2d(sol[i,:,0].cpu(), sol[i,:,1].cpu(), 300, range=((-1*RR,RR), (-1*RR,RR)))

    cmin = 0.0
    cmax = 0.99#torch.quantile(torch.from_numpy(H[0]), 0.99).item()

    norm = cm.colors.Normalize(vmax=cmax, vmin=cmin)
    #data2noiseTransform.inverse(torch.tensor(sol[i]).to(device))[0].detach().cpu()
    # print(img.shape)
    if i==10:
        img=x_tst
        _ = axs[i].hist2d(img[:,0].cpu(), img[:,1].cpu(), 300, range=((-1*RR,RR), (-1*RR,RR)), norm=norm)

    else:
        img=sol[i]
        _ = axs[i].hist2d(img[:,0].cpu(), img[:,1].cpu(), 300, range=((-1*RR,RR), (-1*RR,RR)), norm=norm)

    axs[i].set_aspect('equal')
    axs[i].axis('off')
    if i==10:
        axs[i].set_title('target')
    else:
        axs[i].set_title('t= %.2f' % (T[i]))

plt.tight_layout()
fig.text(0.5, 0.45, 'VANILLA + DOF'+str(dof_og), ha='center')
plt.show()

# %%
# sample with likelihood

T = torch.tensor([1., 0.])  # sample times
T = T.to(device=device)

# grid_size = 200
# x_1 = torch.meshgrid(torch.linspace(-60, 60, grid_size), torch.linspace(-60, 60, grid_size))
# x_1 = torch.stack([x_1[0].flatten(), x_1[1].flatten()], dim=1).to(device)
x_1=x_tst[0:1000,:].to(device)
print(x_1.shape)
# Out:
# torch.Size([1000, 2])

# %%
# from torch.autograd.functional import jacobian
from torch.distributions import Independent, Normal

# %%
# def noise2data_and_reverse_norm(x): #Beware we want likelihood in the space of the actual distribution
#     return(reverse_normalization(data2noiseTransform.inverse(x)[0])) 

# mean=mean.to(device)
# scale=scale.to(device)

# %%
#  noise2data_and_reverse_norm(x_1).shape

# %%
# from functorch import vmap, jacrev
# source distribution is an isotropic gaussian
gaussian_log_density = Independent(Normal(torch.zeros(2, device=device), torch.ones(2, device=device)), 1).log_prob

# compute log likelihood with unbiased hutchinson estimator, average over num_acc
num_acc = 10
log_p_acc = 0

for i in range(num_acc):
    _, log_p = solver.compute_likelihood(x_1=x_1, method='midpoint', step_size=step_size, exact_divergence=False, log_p0=gaussian_log_density)
    # jacobian = jacrev(noise2data_and_reverse_norm)  # Differentiate param wrt t
    # jacobian_term = vmap(jacobian)(data2noiseTransform(x_1)[0]) 
    # jacobian_term=jacobian(noise2data_and_reverse_norm,data2noiseTransform(x_1)[0]) 
    # print(jacobian_term.mean())
    correct_log_p=log_p#-torch.log(0.000001+torch.abs(torch.linalg.det(jacobian_term)))  #MUST CHECCK AGAIN

    log_p_acc += correct_log_p

log_p_acc /= num_acc

# compute with exact divergence not the hutchinson estimator
# _, exact_log_p = solver.compute_likelihood(x_1=x_1, method='midpoint', step_size=step_size, exact_divergence=True, log_p0=gaussian_log_density)

# %%
print("Loglikelihood",log_p_acc.mean())
# Out:
# Loglikelihood tensor(-117.8627, device='cuda:0')
